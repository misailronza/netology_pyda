# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
(long_phrase > short_phrase)
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах. Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*"

# %%
v = int(input('Введите объем в байтах'))
print ('Объем  файла равен', v/1024 , 'Mb')
# Out:
# Введите объем в байтах2000
# Объем  файла равен 1.953125 Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
month = input('Введите месяц: '); day = int(input ('Введите день: '))
if ((month == "Январь") or (month == "январь")):
    date = day;
elif ((month == "Февраль") or (month == "февраль")):
    date = 31 + day;
elif ((month == "Март") or (month == "март")):
    date = 59 + day;
elif ((month == "Апрель") or (month == "апрель")):
    date = 90 + day; 
elif ((month == "Май") or (month == "май")):
    date = 120 + day;
elif ((month == "Июнь") or (month == "июнь")):
    date = 151 + day; 
elif ((month == "Июль") or (month == "июль")):
    date = 181 + day;
elif ((month == "Август") or (month == "август")):
    date = 212 + day;
elif ((month == "Сентябрь") or (month == "сентябрь")):
    date = 243 + day; 
elif ((month == "Октябрь") or (month == "октябрь")):
    date = 273 + day; 
elif ((month == "Ноябрь") or (month == "ноябрь")):
    date = 304 + day; 
elif ((month == "Декабрь") or (month == "декабрь")):
    date = 334 + day;
else:
    print ("Что-то пошло не так...");
    month = input('Введите месяц: '); day = int(input ('Введите день: '));

if (day == 29) and (date == 60):
    print ("Рыбы");
elif (79 < date < 110):
    print ("Овен");
elif (109 < date < 141): 
    print ("Телец");
elif (140 < date < 172):
    print ("Близнецы");
elif (171 < date < 204):
    print ("Рак");
elif (203 < date < 235):
    print ("Лев");
elif (234 < date < 266):
    print ("Дева");
elif (265 < date < 296):
    print ("Весы");
elif (295 < date < 326):
    print ("Скорпион");
elif (325 < date < 356):
    print ("Стрелец");
elif (355 < date) or (date < 20):
    print ("Козерог");
elif (19 < date < 50):    
    print ("Водолей");
elif (49 < date < 80):
    print ("Рыбы");
# Out:
# Введите месяц: Январь
# Введите день: 1
# Козерог

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
income = int(input('Введите заработную плату в месяц: '))
bond = int(input('Введите сколько процентов уходит на ипотеку: '))
life = int(input('Введите сколько процентов уходит на жизнь: '))
bonus = int(input('Введите количество премий за год: '))
if (bond > 100):
    print ("Процентов, сэр...")
    bond = int(input('Введите сколько процентов уходит на ипотеку: '))
elif (life > 100):
    print ("Процентов, сэр...")
    life = int(input('Введите сколько процентов уходит на жизнь: '))

bond_year = income*bond*0.01*12;
print ("На ипотеку было потрачено:  ", bond_year, 'рублей');

saving = income*(100 - bond - life)*0.01*12 + bonus*income*0.5
print ("Было накоплено: ", saving, 'рублей')
# Out:
# Введите заработную плату в месяц: 100000
# Введите сколько процентов уходит на ипотеку: 30
# Введите сколько процентов уходит на жизнь: 50
# Введите количество премий за год: 2
# На ипотеку было потрачено:   360000.0 рублей
# Было накоплено:  340000.0 рублей
